# %%
a = 10
b = 15 
print (a>b)
# Out:
# False

# %%
a = 10 
a-= 0
print(a)
# Out:
# 10

# %%
a = 10 
b = 15
c = 20 
print (a>b or c>b)
print(a ==10 or b==15 )
# Out:
# True
# True

# %%
print("a" in "apple")
print ("c" in "apple")
# Out:
# True
# False

# %%
a = int(input("enter a number"))
b = int(input("enter another number"))
print (f"the sum of this number is {a + b}")
print (f"the product of this number is {a * b}")
print (f"the first number divided by the second number is  {a/b}")
print (f"the square of the number a is {a ** 2}")
print (f"the square of the number a is {a ** 3}")
# Out:
# enter a number 2
# enter another number 3
# the sum of this number is 5
# the product of this number is 6
# the first number divided by the second number is  0.6666666666666666
# the square of the number a is 4
# the square of the number a is 8

# %%
# the average of 2 numbers 
num1 = int(input("enter the first number"))
num2 = int(input("enter the second number"))
average = ( num1 + num2 )/2
print (f"the average of the 2 numbers is {average}")
# Out:
# enter the first number 2
# enter the second number 2
# the average of the 2 numbers is 2.0

# %%
# side length of a square 
length = int(input("enter the length of the square"))
Area = length ** 2 
print (f"the area of the square is {Area}")
# Out:
# enter the length of the square 4
# the area of the square is 16

# %%
length = int(input("enter the length of the rectangle"))
breadth = int(input("enter the breadth of the rectangle"))
Area = length * breadth 
print (f"the area of the rectangle is {Area}")
# Out:
# enter the length of the rectangle 2
# enter the breadth of the rectangle 3
# the area of the rectangle is 6

# %%
# Area od the circle 
radius = float(input("enter the radius of the circle"))
circumference = 2*3.14*radius
print(f"the circumference of the circle is {circumference}")
# Out:
# enter the radius of the circle 2
# the circumference of the circle is 12.56

# %%
# find out your current age 
birthyear = int(input("enter your birth year")

# %%
# input time in hours and convert it to minutes 
minutes = int(input("please enter in minute"))
a - minute // 60
b = minute % 60
print(f"the converted time is {a} hours and {b} minutes")

# another way to do this
# Out:
# please enter in minute 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 # input time in hours and convert it to minutes
#       2 minutes = int(input("please enter in minute"))
# ----> 3 a - minute // 60
#       4 b = minute % 60
#       5 print(f"the converted time is {a} hours and {b} minutes")
#
# NameError: name 'a' is not defined

# %%
seconds = int(input("please enter in seconds"))
print(f"the converted time {seconds//3600} hours, {(seconds%3600)//60} minutes and {seconds%60}")
# Out:
# please enter in seconds 3723
# the converted time 1 hours, 2 minutes and 3

# %%
# converting days into year, month and day 
days = int(input("please enter in days"))
# year = days // 360
# day = days % 30
month = (days % 360)//30
print (f"the converted time {days//360} years, {month} months and {days % 30} days")
# Out:
# please enter in days 56
# the converted time 0 years, 1 months and 26 days

# %%
# if else 
number = int(input("enter a number"))
if number > 60:
    print("paass")
else:
    print("fail")
# Out:
# enter a number 53
# fail

# %%
number = int(input("enter a number"))
if number > 90:
    print("Ourstanding")
elif number > 80:
    print("Excellent")
elif number > 70:
    print("good")
else:
    print("disqualified")
# Out:
# enter a number 89
# Excellent

# %%
number = int(input("enter a number"))
if (number % 3) == 0:
    print("yes it is divisible by 3")
else:
    print("no its not")
# Out:
# enter a number 7
# no its not

# %%
number = int(input("enter a number"))
if (number % 3) ==0 and (number % 5) ==0: 
    print("number is divisible by 3 and 5")
elif (number % 5) ==0: 
    print("number is divisible by 5 only ")
elif (number % 3) ==0: 
    print("number is divisible by 3 only ")
else: 
    print("number is neither divisible by 5 nor 3")
# Out:
# enter a number 20
# number is divisible by 5 only

# %%
if number%3 == 0:
    if number%5! = 0:
        print("Divisible by both")
elif number % 5 ==0 
    print("divisible by 5")
else: 
print("None")
